# %%
import requests
import pandas as pd
import time
from dotenv import load_dotenv
import os
from sqlalchemy import create_engine, text
from fetchers import fetch_data, fetch_fmp_data, fetch_yf
from config import fmp_endpoints
from cleaners import parse_dict_col
import matplotlib.pyplot as plt
from pathlib import Path
import ast

# %%
engine = create_engine("mysql+pymysql://root:Aatroxkalistartop123@localhost:3306/finance_db")

# %%
load_dotenv()
api_key = os.getenv('FMP_api')
fred_api = os.getenv('FRED_api')

# %%
ROOT = Path.cwd().parent
ROOT
# Out:
# WindowsPath('C:/Users/YoungBossTrungNguyen/OneDrive/Documents/Quantitative-Financial-Infrastructure')

# %%
symbols = pd.read_csv(f"{ROOT}/data/comp_info.csv")['ticker'].tolist()

# %%
fetch_fmp_data(symbols[1100:1200], api_key, time_sleep=0.08) #last time
# Out:
# [profile] Progress: 100 / 100 fetched...
# [quote] Progress: 100 / 100 fetched...
# [income-statement] Progress: 100 / 100 fetched...
# [balance-sheet-statement] Progress: 100 / 100 fetched...
# [cash-flow-statement] Progress: 100 / 100 fetched...
# [key-metrics] Progress: 100 / 100 fetched...
# [ratios] Progress: 100 / 100 fetched...
# [financial-scores] Progress: 100 / 100 fetched...
# [enterprise-values] Progress: 100 / 100 fetched...
# [discounted-cash-flow] Progress: 100 / 100 fetched...
# [levered-discounted-cash-flow] Progress: 100 / 100 fetched...
# [income-statement-growth] Progress: 100 / 100 fetched...
# [balance-sheet-statement-growth] Progress: 100 / 100 fetched...
# [cash-flow-statement-growth] Progress: 100 / 100 fetched...
# [financial-growth] Progress: 100 / 100 fetched...
# [revenue-product-segmentation] Progress: 100 / 100 fetched...
# [revenue-geographic-segmentation] Progress: 100 / 100 fetched...
# [dividends] Progress: 100 / 100 fetched...
# ...
